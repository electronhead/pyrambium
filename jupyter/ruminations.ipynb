# %%
mothership/
    jupyter/
    base/
        __init__.py
        service/
            __init__.py
            mothership.py
            action.py
            scheduler.py
            util.py
            continuous.py
        test/
            __init__.py
            test.py
    addendum/
        __init__.py
        service/
            __init__.py
            action.py
        test/
            __init__.py
            test.py
    router/
        main.py
        admin_router.py
        mothership_router.py
    Dockerfile
    docker-compose.yaml
    README.md
    requirements.txt
    venv/

mothership/
    jupyter/
    core/
        __init__.py
        service/
            __init__.py
            mothership.py
        model/
            __init__.py
            action.py
            scheduler.py
        shared/
            __init__.py
            util.py
        schedule/
            continuous.py
        test/
            __init__.py
            test.py
    addendum/
        __init__.py
        code/
            __init__.py
            action.py
        test/
            __init__.py
            test.py
    router/
        main.py
        admin_router.py
        mothership_router.py
    Dockerfile
    docker-compose.yaml
    README.md
    requirements.txt
    venv/
